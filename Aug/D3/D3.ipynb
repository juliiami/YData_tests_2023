# %% [markdown]
# <h1 class="title"><span>(D3)&nbsp;Ski: Optimize</span></h1>
# <table style="border-collapse: collapse;">
#   <tbody>
#     <tr class="time-limit">
#       <td style="border: 2px solid #fff; padding: 5px;" class="property-title">Time limit</td>
#       <td style="border: 2px solid #fff; padding: 5px;">10 seconds</td>
#     </tr>
#   </tbody>
# </table>
# <div>&nbsp;</div>
# <div>In this question you are required to <strong>write code</strong>, implementing a solution to the problem described below.</div>
# <div>You are required to solve the same problem as in D2, but with higher input sizes.</div>
# <h2>Input format</h2>
# <div class="input-specification">
#   <div>One line containing a sequence of numbers separated by space, corresponding to the stations array: <span class="cg-latex">$$Stations[s_1, s_2, \ldots ,s_n ]$$</span>, <span class="cg-latex">$$1 \le n \le 10000$$</span>, <span class="cg-latex">$$0 \le s_i \le 2000$$</span>.</div>
# </div>
# <h2>Output format</h2>
# <div class="output-specification">Print one integer <span>—</span> &nbsp;the <strong>length of the maximum descent</strong> <span>you can obtain from up to 2 routes combined.</span></div>
# <h3>Sample 1</h3>
# <table style="border-collapse: collapse;" class="sample-tests">
#   <thead>
#     <tr>
#       <th style="border: 2px solid #fff; padding: 5px;">Input</th>
#       <th style="border: 2px solid #fff; padding: 5px;">Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 2px solid #fff;">
#         <pre class="content">80 25 8 10 15 30 2</pre>
#       </td>
#       <td style="border: 2px solid #fff; text-align: center;">
#         <pre>100 </pre>
#       </td>
#     </tr>
#   </tbody>
# </table>
# <h3>Sample 2</h3>
# <table style="border-collapse: collapse;" class="sample-tests">
#   <thead>
#     <tr>
#       <th style="border: 2px solid #fff; padding: 5px;">Input</th>
#       <th style="border: 2px solid #fff; padding: 5px;">Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 2px solid #fff; text-align: center;">
#         <pre class="content">80 25 8 10 15 30 100</pre>
#       </td>
#       <td style="border: 2px solid #fff; text-align: center;">
#         <pre>72 </pre>
#       </td>
#     </tr>
#   </tbody>
# </table>
# <h3>Sample 3</h3>
# <table style="border-collapse: collapse;" class="sample-tests">
#   <thead>
#     <tr>
#       <th style="border: 2px solid #fff; padding: 5px;">Input</th>
#       <th style="border: 2px solid #fff; padding: 5px;">Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 2px solid #fff;">
#         <pre class="content">50 60 70 80 90</pre>
#       </td>
#       <td style="border: 2px solid #fff; text-align: center;">
#         <pre>0</pre>
#       </td>
#     </tr>
#   </tbody>
# </table>
# <h2>Notes</h2>
# <div class="notes">Maximum points for question D3:<strong> 13</strong> points.<br><br><!--l. 80-->
#   <p style="text-indent: 0em;"><span style="font-weight: bold;">Reminder: </span>You must select 2 out of 3 questions in programming section: Ski (D), Vehicles (E), Telecom (F), and answer both selected questions as fully as possible (for example, if you choose Ski and Telecom, you should answer questions D1, D2, D3 and F1, F2, F3).</p>
# </div>

# %%
### Initial candidate answer code

# %%
# Use print("Debug messages...") to debug your solution.

def solution(inp):
    # Your code goes here
    return 0

# %%
### Initial candidate test code

# %%
# To use the candidate's code, import the module Answer
import Answer
import numpy as np


# ##DISPLAY_BEGIN##
example1 = '80 25 8 10 15 30 2'
print(example1)
print(Answer.solution(example1), '\n')

example2 = '80 25 8 10 15 30 100'
print(example2)
print(Answer.solution(example2), '\n')

example3 = '50 60 70 80 90'
print(example3)
print(Answer.solution(example3), '\n')
# ##DISPLAY_END##

# %%
### Code validator

# %%
# Add functions to this file, one for each method defined in 
# the Validators declared at the bottom of the page.

# Use assert (condition) to validate/unvalidate the candidate's answer which is
# in the Answer module
from tests import get_data
import Answer
import pandas as pd
import numpy as np
import time
import sys


# TEST DATA
q,a = get_data()

# Example cases are solved correctly
# (weight = 4)
def exampleValidation():
    t0 = time.time()
    sol = []
    ans = []
    for i in range(3):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    t1 = time.time()
    np.testing.assert_array_equal(sol,ans)
    assert((t1-t0)/len(ans) <= 10)

# Correct solution for no possible routes
# (weight = 2)
def zeroValidation():
    t0 = time.time()
    sol = [Answer.solution(q[4]),Answer.solution(q[15]),Answer.solution(q[21])]#,Answer.solution(q[31])]
    ans = [a[4],a[15],a[21]]#,a[31]]
    t1 = time.time()
    np.testing.assert_array_equal(sol,ans)
    assert((t1-t0)/len(ans) <= 10)

# Correct solution for a small number of stations (<=50)
# (weight = 1)
def shortValidation():
    t0 = time.time()
    sol = [Answer.solution(q[3])]
    ans = [a[3]]
    for i in range(5,15):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    t1 = time.time()
    np.testing.assert_array_equal(sol,ans)
    assert((t1-t0)/len(ans) <= 10)

# Correct solution for a medium number of stations (>50 and <1000)
# (weight = 3)
def longValidation():
    t0 = time.time()
    sol = []
    ans = []
    for i in range(16,21):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    for i in range(22,24):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    t1 = time.time()
    np.testing.assert_array_equal(sol,ans)
    assert((t1-t0)/len(ans) <= 10)

# Correct solution for a large number of stations (>=1000)
# (weight = 3)
def superlongValidation():
    t0 = time.time()
    sol = []
    ans = []
    for i in range(24,32):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    t1 = time.time()
    np.testing.assert_array_equal(sol,ans)
    assert((t1-t0)/len(ans) <= 10)

# %%
### Possible solution

# %%
def solution(inp):
    hs = list(map(int, inp.split()))
    sol1 = []
    mx = 0
    for h in hs:
        mx = max(mx, h)
        sol1.append(mx - h)
    sol2 = []
    mn = hs[-1]
    for h in hs[::-1]:
        mn = min(mn, h)
        sol2.append(h - mn)
    result = 0
    best = 0
    sol2.reverse()
    for i in range(len(hs)):
        result = max(result, best + sol2[i])
        best = max(best, sol1[i])
    return(result)
