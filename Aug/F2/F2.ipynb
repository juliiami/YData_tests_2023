# %% [markdown]
# <h1 class="title">(F2)&nbsp;Telecom: Billing</h1>
# <div><span>In this question you are required to<strong>&nbsp;</strong></span><span><strong>write code</strong></span><span>, implementing a solution to the following problem:</span>
#   <p>You are provided with usage data from the telecom operator Megaline. The company oﬀers its clients two prepaid plans, Surf and Ultimate. The plans details are provided below. In addition to the data on calls, you are provided with data of message and web usage for the company’s clients, as well as personal details and subscription type for each user.</p>
#   <p>In the working directory there are the ﬁles <span style="font-family: monospace;">users_data.csv</span>, <span style="font-family: monospace;">calls_data.csv</span>, <span style="font-family: monospace;">msg_data.csv&nbsp;</span> and <span style="font-family: monospace;">web_data.csv</span>.</p>
#   <p>You need to write code that returns the amount a given customer will be billed for in the month of<span>&nbsp;</span><span><strong>December</strong>&nbsp;</span>(12) given their subscription plan and usage data.</p>
#   <p>Given a<span>&nbsp;</span><code><span>user_id</span></code>, ﬁnd their plan type (users data, <code>plan</code> column), and use it to calculate the payment due based on their usage (calls, texts and web data), and return the total amount corresponding to their usage in the provided period (<code>month</code>=12).</p>
#   <p><strong>Note: </strong>Megaline rounds up for calculation of billing. For <strong>calls</strong>, each individual call is rounded up to the next minute: even if the call lasted just <strong>one</strong>&nbsp;second, it will be counted as one minute. For <strong>web traffic</strong>, the total for the month is summed and rounded up (individual web sessions are not rounded up). If someone uses 1.2 gigabytes this month, they will be charged for 2 gigabytes.</p>
#   <p>The plans information is described as follows:</p>
#   <table cellpadding="0" cellspacing="0" width="570" border="0" style="border-collapse: collapse; height: 287px;">
#     <tbody>
#       <tr style="height: 14,40pt;">
#         <td height="24" width="314" style="border: 2px solid #fff; text-align: left;" class="et2"><strong>Plan</strong></td>
#         <td width="90" style="border: 2px solid #fff; text-align: center;" class="et2"><strong>surf</strong></td>
#         <td width="90" style="border: 2px solid #fff; text-align: center;" class="et2"><strong>ultimate</strong></td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="314" style="border: 2px solid #fff; text-align: left;" class="et3">Base payment (monthly)</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">20</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">70</td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="494" colspan="3" style="border: 2px solid #fff; height: 14,40pt; width: 296,40pt;" class="et2"><strong>Base plan coverage</strong></td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="314" style="border: 2px solid #fff; height: 14,40pt; width: 188,40pt;" class="et3">Call time included (min)</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">500</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">3000</td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="46" width="314" style="border: 2px solid #fff; height: 27,60pt; width: 188,40pt;" class="et3">Texts included</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">50</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">1000</td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="314" style="border: 2px solid #fff; height: 14,40pt; width: 188,40pt;" class="et3">Data included (GB)</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">15</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">30</td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="494" colspan="3" style="border: 2px solid #fff; height: 14,40pt; width: 296,40pt;" class="et2"><strong>Costs for usage exceeding plan limits</strong></td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="314" style="border: 2px solid #fff; height: 14,40pt; width: 188,40pt;" class="et3">Calls over limit (per min)</td>
#         <td width="90" style="border: 2px solid #fff; text-align: center;" class="et3">0.03</td>
#         <td width="90" style="border: 2px solid #fff; text-align: center;" class="et3">0.01</td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="314" style="border: 2px solid #fff; height: 14,40pt; width: 188,40pt;" class="et3">Texts over limit</td>
#         <td width="90" style="border: 2px solid #fff; text-align: center;" class="et3">0.03</td>
#         <td width="90" style="border: 2px solid #fff; text-align: center;" class="et3">0.01</td>
#       </tr>
#       <tr style="text-align: left;">
#         <td height="24" width="314" style="border: 2px solid #fff; height: 14,40pt; width: 188,40pt;" class="et3">Data over limit (per GB)</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">10</td>
#         <td width="90" align="right" style="border: 2px solid #fff; text-align: center;" class="et3">7</td>
#       </tr>
#     </tbody>
#   </table>
#   <div>
#     <p>So for example, a user on <strong>surf </strong>plan who used 550 minutes, 42 texts and 16.3 GB of data a month will be billed for 20 + (550-500)*0.03 + (17-15)*10 = 41.5</p>
#   </div>
# </div>
# <h2>Input format</h2>
# <div class="input-specification">
#   <p>One integer - <code>user_id</code><em>&nbsp;</em>corresponding to a user in the subscriptions dataset.</p>
#   <p><strong>Data:</strong></p>
#   <div><span style="font-family: monospace;">users_data.csv</span>&nbsp;(columns&nbsp;<code>user_id</code>,&nbsp;<code>first_name</code>,&nbsp;<code>last_name</code>,&nbsp;<code>plan</code>) &nbsp;<br><span style="font-family: monospace;">calls_data.csv</span>&nbsp;(columns&nbsp;<code>id</code>,&nbsp;<code>user_id</code>,&nbsp;<code>month</code>,&nbsp;<code>duration</code>) &nbsp;<br><span style="font-family: monospace;">msg_data.csv</span>&nbsp;(columns&nbsp;<code>id</code>,&nbsp;<code>user_id</code>,&nbsp;<code>month</code>) &nbsp;<br><span style="font-family: monospace;">web_data.csv</span>&nbsp;(columns&nbsp;<code>id</code>,&nbsp;<code>user_id</code>,&nbsp;<code>month</code>,&nbsp;<code>gb_used</code>)</div>
# </div>
# <h2>Output format</h2>
# <div class="output-specification"><span>Print one ﬂoat value, corresponding to the total payment due based on the users subscription type.</span></div>
# <div class="output-specification">
#   <h3>Sample 1</h3>
#   <table style="border-collapse: collapse;" class="sample-tests">
#     <thead>
#       <tr>
#         <th style="border: 2px solid #fff;">Input</th>
#         <th style="border: 2px solid #fff;">Output</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="border: 2px solid #fff;">
#           <pre class="content">1000</pre>
#         </td>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre>70 </pre>
#         </td>
#       </tr>
#     </tbody>
#   </table>
#   <h3>Sample 2</h3>
#   <table style="border-collapse: collapse;" class="sample-tests">
#     <thead>
#       <tr>
#         <th style="border: 2px solid #fff;">Input</th>
#         <th style="border: 2px solid #fff;">Output</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre class="content">1001</pre>
#         </td>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre>60.0 </pre>
#         </td>
#       </tr>
#     </tbody>
#   </table>
# </div>
# <h2>Notes</h2>
# <div class="notes">Maximum points for question F2:<strong> 10 </strong>points.</div>
# <div class="notes"><br><!--l. 80-->
#   <p style="text-indent: 0em;"><span style="font-weight: bold;">Reminder: </span>You must select 2 out of 3 questions in programming section: Ski (D), Vehicles (E), Telecom (F), and answer both selected questions as fully as possible (for example, if you choose Ski and Telecom, you should answer questions D1, D2, D3 and F1, F2, F3).</p>
# </div>

# %%
### Initial candidate answer code

# %%
# Use print("Debug messages...") to debug your solution.
import pandas as pd

users_data = pd.read_csv("/tmp/deps/users_data.csv", sep=",")
calls_data = pd.read_csv("/tmp/deps/calls_data.csv", sep=",")
msg_data = pd.read_csv("/tmp/deps/msg_data.csv", sep=",")
web_data = pd.read_csv("/tmp/deps/web_data.csv", sep=",")

def solution(userid):
    # Your code goes here
    return 0

# %%
### Initial candidate test code

# %%
# To use the candidate's code, import the module Answer
import Answer
import numpy as np
import pandas as pd
from datetime import datetime

# ##DISPLAY_BEGIN##

users_data = pd.read_csv("/tmp/deps/users_data.csv", sep=",")
calls_data = pd.read_csv("/tmp/deps/calls_data.csv", sep=",")
msg_data = pd.read_csv("/tmp/deps/msg_data.csv", sep=",")
web_data = pd.read_csv("/tmp/deps/web_data.csv", sep=",")

# datasets
print(users_data.head())
print(calls_data.head())
print(msg_data.head())
print(web_data.head())

#input
print(Answer.solution(1000), '\n')

print(Answer.solution(1001), '\n')

# ##DISPLAY_END##

# %%
### Code validator

# %%
# Add functions to this file, one for each method defined in 
# the Validators declared at the bottom of the page.

# Use assert (condition) to validate/unvalidate the candidate's answer which is
# in the Answer module
from tests import get_data
import Answer
import pandas as pd
import numpy as np


# TEST DATA
users_data, calls_data, msg_data, web_data, q, a = get_data()

# Example cases are solved correctly
# (weight = 5)
def exampleValidation():
    sol = []
    ans = []
    for i in range(2):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    np.testing.assert_array_equal(sol,ans)

# Additional test cases are solved correctly
# (weight = 4)
def restValidation():
    sol = []
    ans = []
    for i in range(2,10):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    np.testing.assert_array_equal(sol,ans)

# %%
### Possible solution

# %%
import numpy as np
import pandas as pd

users_data = pd.read_csv("/tmp/deps/users_data.csv", sep=",")
calls_data = pd.read_csv("/tmp/deps/calls_data.csv", sep=",")
msg_data = pd.read_csv("/tmp/deps/msg_data.csv", sep=",")
web_data = pd.read_csv("/tmp/deps/web_data.csv", sep=",")

def solution(userid):
    month = 12
    plan_dict = {'surf': {
        'base_payment': 20,
        'coverage_call': 500,
        'coverage_text': 50,
        'coverage_data': 15,
        'cost_call': 0.03,
        'cost_text': 0.03,
        'cost_data': 10
    },
    'ultimate': {
        'base_payment': 70,
        'coverage_call': 3000,
        'coverage_text': 1000,
        'coverage_data': 30,
        'cost_call': 0.01,
        'cost_text': 0.01,
        'cost_data': 7
    }}
    curr_plan = users_data[users_data['user_id'] == userid]['plan'].values[0]
    curr_texts = msg_data.loc[(msg_data['user_id'] == userid) & (msg_data['month'] == month)].shape[0]
    curr_call = int(np.ceil(calls_data.loc[(calls_data['user_id'] == userid) & (calls_data['month'] == month)]['duration']).sum())
    curr_web = np.ceil(web_data.loc[(web_data['user_id'] == userid) & (web_data['month'] == month)]['gb_used'].sum())
    payment = plan_dict[curr_plan]['base_payment']
    if curr_call > plan_dict[curr_plan]['coverage_call']:
        payment = payment + (curr_call - plan_dict[curr_plan]['coverage_call'])*plan_dict[curr_plan]['cost_call']
    if curr_texts > plan_dict[curr_plan]['coverage_text']:
        payment = payment + (curr_texts - plan_dict[curr_plan]['coverage_text']) * plan_dict[curr_plan]['cost_text']
    if curr_web > plan_dict[curr_plan]['coverage_data']:
        payment = payment + (curr_web - plan_dict[curr_plan]['coverage_data']) * plan_dict[curr_plan]['cost_data']
    return payment
