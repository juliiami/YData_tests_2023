# %% [markdown]
# <div class="problem-statement">
#   <div class="header">
#     <h1 class="title">(F1)&nbsp;Streaming: Rank</h1>
#   </div>
#   <div class="legend">In this question you are required to <span style="font-weight: bold;">write code</span>, implementing a solution to the following problem. <!--l. 52-->
#     <p style="text-indent: 0em;">In the working directory there is a ﬁle <span style="font-family: monospace;">stream_data.csv</span>. <!--l. 56--></p>
#     <p>You are provided with data from a popular streaming platform, comparing the channels performance for the past year, and are tasked with ﬁnding insights and patterns in the data. <br>Dataset description:</p>
#     <ul>
#       <li><span></span><code>ChannelID</code>: Individual channel ID</li>
#       <li><span></span><code>Watch time</code>: Total watch time for the channel in minutes (for all viewers)</li>
#       <li><span></span><code>Stream time</code>: Total stream time for the channel in minutes (combined duration of all videos)</li>
#       <li><span></span><code>Peak viewers</code>: Maximum number of online viewers at any point during the past year</li>
#       <li><span></span><code>Average viewers</code>: Average number of online viewers during the past year</li>
#       <li><span></span><code>Followers total</code>: Total number of followers for the channel at the end of the year</li>
#       <li><span></span><code>Followers gained</code>: Number of followers who subscribed during the past year</li>
#       <li><span></span><code>Views gained</code>: Number of new views accumulated during the past year</li>
#       <li><span></span><code>Partnership</code>: Registration to the platform’s partnership program (TRUE/FALSE)</li>
#       <li><span></span><code>Mature</code>: Does the channel include content rated as mature (TRUE/FALSE)</li>
#       <li><span></span><code>Language</code>: Channel’s primary language</li>
#     </ul>
#     <div>
#       <p>You are requested to write code solving the following task: given <code>ChannelID</code>, ﬁnd out where it’s ranked for each of the numeric parameters, and return the average rank for that channel. For each numeric parameter (<code>Watch time</code>, <code>Stream time</code>,&nbsp;<code>Peak viewers</code>, <code>Average viewers</code>, <code>Followers total</code>, <code>Followers gained</code>,&nbsp;<code>Views gained</code>), ﬁnd out where the target channel is ranked in the dataset. Calculate and return the <strong>average rank </strong>for the channel, rounded to <strong>2 decimal digits</strong>.</p>
#       <p>Assign the ranks in the range 1-1000 to each parameter so the 1st ranked channel in each is the one with the highest value for the parameter. In case of ties, all tied channels should receive <strong>the lowest </strong>available rank, but the next rank is skipped. For example, if the parameter values are: <code>[100, 200, 400, 200, 200]</code>, the ranks returned should be: <code>[5, 2, 1, 2, 2]</code>.</p>
#     </div>
#   </div>
#   <h2>Input format</h2>
#   <div class="input-specification">
#     <p>One integer — <code>ChannelID</code>.</p>
#     <!--l. 69-->
#     <p style="text-indent: 0em;"><span style="font-weight: bold;">Data</span>:<br><span style="font-family: monospace;">stream_data.csv</span>&nbsp;</p>
#   </div>
#   <h2>Output format</h2>
#   <div class="output-specification">
#     <p>Print one numeric value, rounded to 2 decimal digits: the average of the channel’s individual rankings for the diﬀerent parameters.</p>
#   </div>
#   <h3>Sample 1</h3>
#   <table class="sample-tests" style="height: 72px; border-collapse: collapse;" width="175">
#     <thead>
#       <tr>
#         <th style="border: 2px solid #fff;">Input</th>
#         <th style="border: 2px solid #fff;">Output</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre class="content">21779</pre>
#         </td>
#         <td style="border: 2px solid #fff; text-align: center;">
#           <pre>134.71</pre>
#         </td>
#       </tr>
#     </tbody>
#   </table>
#   <div>
#     <h3>Sample 2</h3>
#     <table class="sample-tests" style="height: 72px; border-collapse: collapse;" width="175">
#       <thead>
#         <tr>
#           <th style="border: 2px solid #fff;">Input</th>
#           <th style="border: 2px solid #fff;">Output</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre class="content">28640</pre>
#           </td>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre>124.86</pre>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
#   <div>
#     <h3>Sample 3</h3>
#     <table class="sample-tests" style="height: 72px; border-collapse: collapse;" width="175">
#       <thead>
#         <tr>
#           <th style="border: 2px solid #fff;">Input</th>
#           <th style="border: 2px solid #fff;">Output</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre class="content">28159</pre>
#           </td>
#           <td style="border: 2px solid #fff; text-align: center;">
#             <pre>362.29</pre>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
#   <h3>Notes</h3>
#   <div class="notes">Maximum points for question F1: <span style="font-weight: bold;">7 </span>points.</div>
#   <div class="notes">&nbsp;</div>
#   <div class="notes"><!--l. 80-->
#     <p style="text-indent: 0em;"><span style="font-weight: bold;">Reminder: </span>You must select 2 out of 3 questions in programming section: Sums (D), Countries (E), Streaming (F), and answer both selected questions as fully as possible (for example, if you choose Sums and Streaming, you should answer questions D1, D2, D3 and F1, F2, F3).</p>
#   </div>
# </div>

# %%
### Initial candidate answer code

# %%
# Use print("messages...") to debug your solution.
import numpy as np
import pandas as pd

stream_data = pd.read_csv('/tmp/deps/stream_data.csv', sep=",")

def solution(ChannelID):
    # Your code goes here
    return 0

# %%
### Initial candidate test code

# %%
# To use the candidate's code, import the module Answer
import Answer
import numpy as np
import pandas as pd
from datetime import datetime

# ##DISPLAY_BEGIN##

stream_data = pd.read_csv('/tmp/deps/stream_data.csv', sep=",")
print(stream_data.head())

print(Answer.solution(21779), '\n')

print(Answer.solution(28640), '\n')

print(Answer.solution(28159), '\n')

# ##DISPLAY_END##

# %%
### Code validator

# %%
# Add functions to this file, one for each method defined in 
# the Validators declared at the bottom of the page.

# Use assert (condition) to validate/unvalidate the candidate's answer which is
# in the Answer module
from tests import get_data
import Answer
import pandas as pd
import numpy as np


# TEST DATA
stream_data, q, a = get_data()

# Example cases are solved correctly
# (weight = 5)
def exampleValidation():
    sol = []
    ans = []
    for i in range(3):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    np.testing.assert_array_equal(sol,ans)

# Additional test cases are solved correctly
# (weight = 4)
def restValidation():
    sol = []
    ans = []
    for i in range(3,10):
        sol.append(Answer.solution(q[i]))
        ans.append(a[i])
    np.testing.assert_array_equal(sol,ans)

# %%
### Possible solution

# %%
import pandas as pd
import numpy as np

stream_data = pd.read_csv('/tmp/deps/stream_data.csv', sep=",")

def solution(ChannelID):
    res = stream_data.iloc[:,1:8].rank(axis=0, method='min', ascending=False).mean(axis=1).round(2)
    idx = stream_data[stream_data.ChannelID==ChannelID].index[0]
    return(res[idx])
